# %%
age = 18

if age < 20 :
    '''
    #未成年の場合
    print('ジュースで乾杯')
else :
    #成年の場合
    '''
    print('お酒で乾杯')
# Out:
# お酒で乾杯

# %%
print('降水確率' + str(50) + '%')
# Out:
# 降水確率50%

# %%
print('バカ'*5)
# Out:
# バカバカバカバカバカ

# %%
last_name = '侍'
first_name = '太郎'
sister_name = '花子'

print(f'私の名前は{last_name}{first_name}です。')
print(f'私の姉の名前は{last_name}{sister_name}です。')
# Out:
# 私の名前は侍太郎です。
# 私の姉の名前は侍花子です。

# %%
jouhen = 10
kahen = 20
height = 5

menseki = ( jouhen + kahen ) * height /2
print(f'台形の面積={menseki}cm2')
# Out:
# 台形の面積=75.0cm2
